# %% [markdown]
# **Task 06: Modifying RDF(s)**

# %%
# !pip install rdflib 
github_storage = "https://raw.githubusercontent.com/FacultadInformatica-LinkedData/Curso2020-2021/master/Assignment4"
# Out:
# Requirement already satisfied: rdflib in /usr/local/lib/python3.6/dist-packages (5.0.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.6/dist-packages (from rdflib) (0.6.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from rdflib) (1.15.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib) (2.4.7)

# %% [markdown]
# Leemos el fichero RDF de la forma que lo hemos venido haciendo

# %%
from rdflib import Graph, Namespace, Literal
from rdflib.namespace import RDF, RDFS
g = Graph()
g.namespace_manager.bind('ns', Namespace("http://somewhere#"), override=False)
g.namespace_manager.bind('vcard', Namespace("http://www.w3.org/2001/vcard-rdf/3.0#"), override=False)
g.parse(github_storage+"/resources/example5.rdf", format="xml")
# Out:
# <Graph identifier=N86a3b12b01a84589b2f1bc49623581ca (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Create a new class named Researcher

# %%
ns=Namespace("somewhere#")
g.add((ns.Researcher, RDF.type, RDFS.Class))
for s, p, o in g:
  print(s,p,o)
# Out:
# somewhere#JaneSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type somewhere#Researcher
# somewhere#Researcher http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Given John
# somewhere#UPM http://www.w3.org/1999/02/22-rdf-syntax-ns#type somewhere#University
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Family Jones
# somewhere#johnSmith http://www.w3.org/2001/vcard-rdf/3.0/work somewhere#UPM
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/FN Sara Jones
# http://somewhere#SaraJones http://www.w3.org/2001/vcard-rdf/3.0/Given Sara
# http://www.w3.org/2001/vcard-rdf/3.0/FN http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype
# http://somewhere#SaraJones http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#JohnSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Person
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# somewhere#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf somewhere#Person
# somewhere#University http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://somewhere#JohnSmith http://www.w3.org/2001/vcard-rdf/3.0/FN John Smith
# somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0/Family Smith
# somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0/Given Jane
# http://somewhere#Person http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Property
# somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0/FN Jane Smith
# http://www.w3.org/2001/vcard-rdf/3.0/Given http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string
# http://www.w3.org/2001/vcard-rdf/3.0/Family http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2001/XMLSchema#string

# %% [markdown]
# **TASK 6.1: Create a new class named "University"**

# %%
g.add((ns.University, RDF.type, RDFS.Class))

# %% [markdown]
# **TASK 6.2: Add "Researcher" as a subclass of "Person"**

# %%
g.add((ns.Researcher, RDFS.subClassOf, ns.Person))

# %% [markdown]
# **TASK 6.3: Create a new individual of Researcher named "Jane Smith"**

# %%
g.add((ns.JaneSmith, RDF.type, ns.Researcher))

# %% [markdown]
# **TASK 6.4: Add to the individual JaneSmith the fullName, given and family names**

# %%
vcard = Namespace("http://www.w3.org/2001/vcard-rdf/3.0/")
g.add((ns.JaneSmith, vcard.FN, Literal("Jane Smith")))
g.add((ns.JaneSmith, vcard.Given, Literal("Jane")))
g.add((ns.JaneSmith, vcard.Family, Literal("Smith")))

# %% [markdown]
# **TASK 6.5: Add UPM as the university where John Smith works**

# %%
g.add((ns.UPM, RDF.type, ns.University))
g.add((ns.johnSmith, vcard.work, ns.UPM))
