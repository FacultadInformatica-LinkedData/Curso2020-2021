# %% [markdown]
# **Task 06: Modifying RDF(s)**

# %%
# !pip install rdflib 
github_storage = "https://raw.githubusercontent.com/FacultadInformatica-LinkedData/Curso2020-2021/master/Assignment4"
# Out:
# Requirement already satisfied: rdflib in /usr/local/lib/python3.6/dist-packages (5.0.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.6/dist-packages (from rdflib) (0.6.0)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from rdflib) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from rdflib) (1.15.0)

# %% [markdown]
# Leemos el fichero RDF de la forma que lo hemos venido haciendo

# %%
from rdflib import Graph, Namespace, Literal
from rdflib.namespace import RDF, RDFS
g = Graph()
g.namespace_manager.bind('ns', Namespace("http://somewhere#"), override=False)
g.namespace_manager.bind('vcard', Namespace("http://www.w3.org/2001/vcard-rdf/3.0#"), override=False)
g.parse(github_storage+"/resources/example5.rdf", format="xml")
# Out:
# <Graph identifier=Nd2b02499fb2a44cdb9e08c58afa18de8 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Create a new class named Researcher

# %%
ns = Namespace("http://somewhere#")
VCARD = Namespace("http://www.w3.org/2001/vcard-rdf/3.0#")

g.add((ns.Researcher, RDF.type, RDFS.Class))
for s, p, o in g:
  print(s,p,o)

# %% [markdown]
# **TASK 6.1: Create a new class named "University"**

# %%
g.add((ns.University, RDF.type, RDFS.Class))
for s,p,o in g.triples((None,RDF.type,RDFS.Class)):
  print(s,p,o)

# %% [markdown]
# **TASK 6.2: Add "Researcher" as a subclass of "Person"**

# %%
g.add((ns.Researcher, RDFS.subClassOf, ns.Person))
for s,p,o in g.triples((None,RDFS.subClassOf,ns.Person)):
  print(s,p,o)
# Out:
# http://somewhere#Researcher http://www.w3.org/2000/01/rdf-schema#subClassOf http://somewhere#Person

# %% [markdown]
# **TASK 6.3: Create a new individual of Researcher named "Jane Smith"**

# %%
g.add((ns.JaneSmith,RDF.type, ns.Researcher))
for s,p,o in g.triples((None,RDF.type,ns.Researcher)):
  print(s,p,o)

# %% [markdown]
# **TASK 6.4: Add to the individual JaneSmith the fullName, given and family names**

# %%
from rdflib import XSD
g.add((ns.JaneSmith,VCARD.FN,Literal('Jane Smith', datatype=XSD.string)))
g.add((ns.JaneSmith,VCARD.Family,Literal('Smith', datatype=XSD.string)))
g.add((ns.JaneSmith,VCARD.Given,Literal('Jane', datatype=XSD.string)))
for s,p,o in g.triples((ns.JaneSmith,None,None)):
  print(s,p,o)
# Out:
# http://somewhere#JaneSmith http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#Researcher
# http://somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0#Given Jane
# http://somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0#FN Jane Smith
# http://somewhere#JaneSmith http://www.w3.org/2001/vcard-rdf/3.0#Family Smith

# %% [markdown]
# **TASK 6.5: Add UPM as the university where John Smith works**

# %%
FOAF = Namespace("http://xmlns.com/foaf/0.1/")
g.add((ns.UPM,RDF.type,ns.University))
g.add((ns.JohnSmith,FOAF.workplaceHomepage,ns.UPM))
for s,p,o in g.triples((None,RDF.type,ns.University)):
  print(s,p,o)
for s,p,o in g.triples((ns.JohnSmith,FOAF.workplaceHomepage,None)):
  print(s,p,o)
# Out:
# http://somewhere#UPM http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://somewhere#University
# http://somewhere#JohnSmith http://xmlns.com/foaf/0.1/workplaceHomepage http://somewhere#UPM
